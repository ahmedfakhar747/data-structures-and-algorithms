# %% [markdown]
# <a href="https://www.kaggle.com/code/ahmedfakhar123/knapsack-masterclass-from-recursion-to-dynamic-pr?scriptVersionId=310400646" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ---
#
# # ⚖️ Knapsack Problem — 3 Levels of Optimization
#
# ---
#
# ## ❓ Problem Statement
#
# > Imagine you're building your ultimate football squad ⚽ with a limited budget.
#
# Each player has a **cost** and a **rating**, and you want to pick the best combination such that:
#
# * Total cost stays within your budget 💰
# * Total team rating is maximized ⭐
#
# There’s no restriction on team size — just choose wisely.
#
#
# ### 🧠 General Form
#
# In computer science terms, this becomes the **Knapsack Problem**:
#
# * You are given **n items**
# * Each item has:
#
#   * ⚖️ weight
#   * 💎 profit
#
# 🎯 Goal:
#
# * Total weight ≤ **W (capacity)**
# * Maximize total profit
#
#
# <img src="https://i.imgur.com/4O919vu.png" width="400">
#
#
# ### 🔥 Why It Matters
#
# This problem models real-world optimization like:
#
# * Resource allocation
# * Packing & logistics
# * Smart decision making
#
# ---
#
# ## ⚡ What’s Next
#
# We’ll solve this in 3 levels:
#
# * 🐢 Brute Force
# * 🚀 Memoization Approach
# * ⚡ Dynamic Programming

# %% [markdown]
# ---
#
# ## 📥 Input
#
# * `weights` → list of item weights ⚖️
# * `profits` → list of corresponding profits 💎
# * `capacity` → maximum weight allowed 🎒
#
# ---
#
# ## 📤 Output
#
# * `max_profit` → maximum profit achievable within given capacity
#
# ---
#
# ## 🧠 Function Signature
#
# Based on this, we can define our function as:

# %%
def max_profit(weights, profits, capacity):
    pass

# %% [markdown]
# ---
#
# ## 🧪 Test Cases
#
# To fully validate our solution, we should cover different scenarios:
#
# * **General case** → mix of items where optimal selection matters
# * **All items fit** → total weight is within capacity
# * **No item fits** → capacity is too small
# * **Single item choice** → only one item can be selected

# %%
test0 = {
    'input': {
        'capacity': 165,
        'weights': [23, 31, 29, 44, 53, 38, 63, 85, 89, 82],
        'profits': [92, 57, 49, 68, 60, 43, 67, 84, 87, 72]
    },
    'output': 309
}

test1 = {
    'input': {
        'capacity': 3,
        'weights': [4, 5, 6],
        'profits': [1, 2, 3]
    },
    'output': 0
}

test2 = {
    'input': {
        'capacity': 4,
        'weights': [4, 5, 1],
        'profits': [1, 2, 3]
    },
    'output': 3
}

test3 = {
    'input': {
        'capacity': 170,
        'weights': [41, 50, 49, 59, 55, 57, 60],
        'profits': [442, 525, 511, 593, 546, 564, 617]
    },
    'output': 1735
}

test4 = {
    'input': {
        'capacity': 15,
        'weights': [4, 5, 6],
        'profits': [1, 2, 3]
    },
    'output': 6
}

test5 = {
    'input': {
        'capacity': 15,
        'weights': [4, 5, 1, 3, 2, 5],
        'profits': [2, 3, 1, 5, 4, 7]
    },
    'output': 19
}

# %%
tests = [test0, test1, test2, test3, test4, test5]

# %% [markdown]
# ---
#
# ## 🧪 Testing Function
#
# We can test our implementation in two simple ways:
#
# * Directly call the function with inputs
# * Use the `evaluate_test_case` helper for structured testing
#
# 💡 **Note:**
# This is just test harness setup — feel free to skip it if you’re only focused on understanding the core logic.

# %%
import time


def evaluate_test_case(function, test_case):
    try:
        start = time.perf_counter()
        result = function(**test_case["input"])
        end = time.perf_counter()

        expected = test_case["output"]
        passed = result == expected
        time_used = end - start

        return result, passed, time_used, None

    except Exception as e:
        return None, False, 0.0, e

def evaluate_test_cases(function, test_cases, error_only=False, summary_only=False):
    print("=" * 100)
    results = []
    total_time = 0.0

    for i, test_case in enumerate(test_cases):
        result, passed, time_used, error = evaluate_test_case(function, test_case)
        results.append((result, passed, time_used, error))
        total_time += time_used

        if summary_only:
            continue
        if error_only and passed:
            continue

        print(f"\n\033[1mTEST CASE #{i}\033[0m")
        print("Input:", test_case["input"])
        print("Expected:", test_case["output"])

        if error:
            print("\033[91mError:\033[0m", error)
        elif passed:
            print(f"\033[92mPassed ✔\033[0m  Time: {time_used:.6f}s")
        else:
            print(f"\033[91mFailed ✘\033[0m  Time: {time_used:.6f}s")
            print("Got:", result)

    total = len(results)
    passed_count = sum(1 for r in results if r[1])

    print("\n\033[1mSUMMARY\033[0m")
    print(
        f"TOTAL: {total}, \033[92mPASSED\033[0m: {passed_count}, \033[91mFAILED\033[0m: {total - passed_count}"
    )
    print(f"TOTAL TIME: {total_time:.2f}s")
    print("=" * 100)
    return results

# %% [markdown]
# ---
#
# ## 🌀 Solution — Recursive Approach
#
# <img src="https://i.imgur.com/eaJzv02.png" width="400">
#
# We solve this problem by thinking **decision by decision** at each index.
#
# At every step, we ask:
#
# > “Should I take this item… or skip it?”
#
#
# ### 🔁 Core Idea
#
# We define a recursive function:
#
# ```python
# max_profit(idx, capacity)
# ```
#
# This means:
#
# > Maximum profit we can get starting from index `idx` with remaining capacity.
#
#
# ### ⚡ Decisions at Each Step
#
# For every item, we have two choices:
#
# * ❌ **Skip the item**
#   Move to next index without changing capacity
#
# * ✅ **Pick the item** *(only if it fits)*
#   Add its profit and reduce remaining capacity
#
#
# ### 🔍 Cases
#
# * If `weights[idx] > capacity`
#   → We **cannot pick** it, so just skip
#
# * Otherwise:
#   → Take the **maximum** of:
#
#   * Skipping the item
#   * Picking the item
#
#
# ### 🛑 Base Case
#
# * If we reach the end (`idx == n`)
#   → No items left → profit = **0**
#
#
# ### 🧩 Recursion Tree (Intuition)
#
# <img src="https://media.geeksforgeeks.org/wp-content/uploads/20260218182009914083/group_3361.webp" width="700">
#
# This tree shows how we explore **all possible combinations** — which is why this approach is simple but not efficient.
#
# 💡 This approach is intuitive, but it explores **all subsets (2ⁿ)** — we’ll optimize this next using DP.

# %% [markdown]
# ###  💻 Implementation

# %%
def max_profit_recursive(weights, profits, capacity, idx=0):
    if idx == len(weights):
        return 0
    elif weights[idx] > capacity:
        return max_profit_recursive(weights, profits, capacity, idx+1)
    else:
        option1 = max_profit_recursive(weights, profits, capacity, idx+1)
        option2 = profits[idx] + max_profit_recursive(weights, profits, capacity - weights[idx], idx+1)
        return max(option1, option2)

# %% [markdown]
# ### 📝 Testing Our Algorithm:

# %%
evaluate_test_cases(max_profit_recursive, tests)
# Out:
# ====================================================================================================
#
# TEST CASE #0
# Input: {'capacity': 165, 'weights': [23, 31, 29, 44, 53, 38, 63, 85, 89, 82], 'profits': [92, 57, 49, 68, 60, 43, 67, 84, 87, 72]}
# Expected: 309
# Passed ✔  Time: 0.000101s
#
# TEST CASE #1
# Input: {'capacity': 3, 'weights': [4, 5, 6], 'profits': [1, 2, 3]}
# Expected: 0
# Passed ✔  Time: 0.000002s
#
# TEST CASE #2
# Input: {'capacity': 4, 'weights': [4, 5, 1], 'profits': [1, 2, 3]}
# Expected: 3
# Passed ✔  Time: 0.000003s
#
# TEST CASE #3
# Input: {'capacity': 170, 'weights': [41, 50, 49, 59, 55, 57, 60], 'profits': [442, 525, 511, 593, 546, 564, 617]}
# Expected: 1735
# Passed ✔  Time: 0.000056s
#
# TEST CASE #4
# Input: {'capacity': 15, 'weights': [4, 5, 6], 'profits': [1, 2, 3]}
# Expected: 6
# Passed ✔  Time: 0.000004s
#
# TEST CASE #5
# Input: {'capacity': 15, 'weights': [4, 5, 1, 3, 2, 5], 'profits': [2, 3, 1, 5, 4, 7]}
# Expected: 19
# Passed ✔  Time: 0.000023s
#
# SUMMARY
# TOTAL: 6, PASSED: 6, FAILED: 0
# TOTAL TIME: 0.00s
# ====================================================================================================
# [(309, True, 0.00010070999999811647, None),
#  (0, True, 2.3999999996249244e-06, None),
#  (3, True, 3.187999993770063e-06, None),
#  (1735, True, 5.626200001529469e-05, None),
#  (6, True, 4.4330000150694104e-06, None),
#  (19, True, 2.3120999998127445e-05, None)]

# %% [markdown]
# ### 📊 Analyzing the Complexity
#
# Here’s what the recursion tree looks like for our approach:
#
# <img src="https://i.imgur.com/WsKTC6I.png" width="640">
#
# Each item creates **two branches** — one for **picking it** and one for **skipping it**.
#
# 💡 **Time Complexity:**
#
# * In the worst case, we explore **all possible subsets**
# * That’s **O(2ⁿ)** — exponential time
#
# ⚠️ For small inputs, recursion is fine, but it **gets slow very quickly** as n grows.
# Next, we’ll see how **dynamic programming** can optimize this dramatically.

# %% [markdown]
# ---
#
# ## 🧠 Solution — Memoization Approach
#
# Recursion is simple, but it **recomputes the same subproblems** again and again.
#
# 💡 **Idea:** Store results of subproblems in a **memo table** so we can reuse them instead of recalculating.
#
# * Each subproblem is uniquely defined by `(idx, capacity)`
# * If we’ve already solved it, **return the stored result**
# * Otherwise, compute it recursively and **save it for future use**
#
# This converts our **exponential recursive solution** into a much faster **polynomial-time algorithm**.

# %%
def max_profit_memo(weights, profits, capacity):
    memo = {}

    def recurse(idx, remaining):
        key = (idx, remaining)

        if key in memo:
            return memo[key]
            
        elif idx == len(weights):
            memo[key] = 0
            
        elif weights[idx] > remaining:
            memo[key] = recurse(idx+1, remaining)

        else:
            memo[key] = max(recurse(idx+1, remaining),
                           profits[idx] + recurse(idx+1, remaining-weights[idx]))
        return memo[key]

    return recurse(0, capacity)

# %% [markdown]
# ### Testing our ALGORITHM:

# %%
evaluate_test_cases(max_profit_memo, tests)
# Out:
# ====================================================================================================
#
# TEST CASE #0
# Input: {'capacity': 165, 'weights': [23, 31, 29, 44, 53, 38, 63, 85, 89, 82], 'profits': [92, 57, 49, 68, 60, 43, 67, 84, 87, 72]}
# Expected: 309
# Passed ✔  Time: 0.000221s
#
# TEST CASE #1
# Input: {'capacity': 3, 'weights': [4, 5, 6], 'profits': [1, 2, 3]}
# Expected: 0
# Passed ✔  Time: 0.000004s
#
# TEST CASE #2
# Input: {'capacity': 4, 'weights': [4, 5, 1], 'profits': [1, 2, 3]}
# Expected: 3
# Passed ✔  Time: 0.000005s
#
# TEST CASE #3
# Input: {'capacity': 170, 'weights': [41, 50, 49, 59, 55, 57, 60], 'profits': [442, 525, 511, 593, 546, 564, 617]}
# Expected: 1735
# Passed ✔  Time: 0.000071s
#
# TEST CASE #4
# Input: {'capacity': 15, 'weights': [4, 5, 6], 'profits': [1, 2, 3]}
# Expected: 6
# Passed ✔  Time: 0.000009s
#
# TEST CASE #5
# Input: {'capacity': 15, 'weights': [4, 5, 1, 3, 2, 5], 'profits': [2, 3, 1, 5, 4, 7]}
# Expected: 19
# Passed ✔  Time: 0.000055s
#
# SUMMARY
# TOTAL: 6, PASSED: 6, FAILED: 0
# TOTAL TIME: 0.00s
# ====================================================================================================
# [(309, True, 0.00022076700000184246, None),
#  (0, True, 3.7439999971411453e-06, None),
#  (3, True, 5.443999981480374e-06, None),
#  (1735, True, 7.081900000116548e-05, None),
#  (6, True, 9.167999991177567e-06, None),
#  (19, True, 5.5217999999968015e-05, None)]

# %% [markdown]
# ## Solution - using dynamic programming:
#
# 1. Create a table of size `(n+1) * (capacity+1)` consisting of all 0s, where is `n` is the number of elements. `table[i][c]` represents the maximum profit that can be obtained using the first `i` elements if the maximum capacity is `c`.
#
# 2. We'll fill the table row by row and column by column. `table[i][c]` can be filled using some values in the row above it.
#
# 3. If `weights[i] > c` i.e. if the current element can is larger than capacity, then `table[i][c]` is simply equal to `table[i-1][c]` (since there's no way we can pick this element).
#
# 4. If `weights[i] <= c` then we have two choices: to either pick the current element or not. We can compare the maximum profit for both these options and pick the better one as the value of `table[i][c]`.
#
#     A. If we don't pick  the element with weight `weights[i]`, then once again the maximum profit is `table[i-1][c]`
#
#     B. If we pick the element with weight `weights[i]`, then the maximum profit is `profits[i] + table[i-1][c-weights[i]]`, since we have used up some capacity.

# %%
def max_profit_dp(weights, profits, capacity):
    n = len(weights)
    table = [ [0 for _ in range(capacity+1) ] for _ in range(n+1)]
    for i in range(n):
        for c in range(1, capacity+1):
            if weights[i] > c:
                table[i+1][c] = table[i][c]
            else:
                table[i+1][c] = max(table[i][c],
                                   profits[i] + table[i][c-weights[i]])
    return table[-1][-1]

# %% [markdown]
# ### Testing our ALGORITHM:

# %%
evaluate_test_cases(max_profit_dp, tests)
# Out:
# ====================================================================================================
#
# TEST CASE #0
# Input: {'capacity': 165, 'weights': [23, 31, 29, 44, 53, 38, 63, 85, 89, 82], 'profits': [92, 57, 49, 68, 60, 43, 67, 84, 87, 72]}
# Expected: 309
# Passed ✔  Time: 0.000404s
#
# TEST CASE #1
# Input: {'capacity': 3, 'weights': [4, 5, 6], 'profits': [1, 2, 3]}
# Expected: 0
# Passed ✔  Time: 0.000005s
#
# TEST CASE #2
# Input: {'capacity': 4, 'weights': [4, 5, 1], 'profits': [1, 2, 3]}
# Expected: 3
# Passed ✔  Time: 0.000006s
#
# TEST CASE #3
# Input: {'capacity': 170, 'weights': [41, 50, 49, 59, 55, 57, 60], 'profits': [442, 525, 511, 593, 546, 564, 617]}
# Expected: 1735
# Passed ✔  Time: 0.000312s
#
# TEST CASE #4
# Input: {'capacity': 15, 'weights': [4, 5, 6], 'profits': [1, 2, 3]}
# Expected: 6
# Passed ✔  Time: 0.000014s
#
# TEST CASE #5
# Input: {'capacity': 15, 'weights': [4, 5, 1, 3, 2, 5], 'profits': [2, 3, 1, 5, 4, 7]}
# Expected: 19
# Passed ✔  Time: 0.000026s
#
# SUMMARY
# TOTAL: 6, PASSED: 6, FAILED: 0
# TOTAL TIME: 0.00s
# ====================================================================================================
# [(309, True, 0.00040380499999059793, None),
#  (0, True, 5.4140000145253e-06, None),
#  (3, True, 6.423000002087065e-06, None),
#  (1735, True, 0.00031233999999358275, None),
#  (6, True, 1.4405000001715962e-05, None),
#  (19, True, 2.63050000057774e-05, None)]

# %% [markdown]
# ### Analysing the Complexity:
#
# The complexity of the dynamic programming solution is **O(n × capacity)**

# %% [markdown]
# ## Conclusion:
#
# The Knapsack Problem was implemented using three different approaches: recursion, memoization, and dynamic programming. Each approach demonstrated clear differences in efficiency and scalability.
#
# * **Recursive approach** is the most intuitive and easiest to implement, but it is highly inefficient due to repeated subproblem calculations, resulting in exponential time complexity.
#
# * **Memoization (Top-Down DP)** significantly improves performance by caching previously computed results, reducing time complexity to polynomial. However, it still uses recursion, which adds overhead due to function calls and stack usage.
#
# * **Dynamic Programming (Bottom-Up DP)** provides the most optimized solution. It eliminates recursion entirely and builds the solution iteratively, making it faster and more memory-efficient in practice.
